# %% [markdown]
# # Genetic Algorithm for EV charging stations

# %%
import networkx as nx
import numpy as np
import random
from typing import List, Tuple, Optional

from modules.genetic import GeneticAlgortihm
#SEED = 4321

# %%
WIDTH = 30
HEIGHT = 30
POI = 10
CHARGERS = 3
NEW_CHARGERS = 4

gen = GeneticAlgortihm(WIDTH, HEIGHT, POI, CHARGERS, NEW_CHARGERS)
gen.init_population()
gen.draw_grid()

# %%
gen.run()
print("Best Solution:\t", gen.new_charging_nodes, "\nGeneration:\t", gen.best_generation,  "\nFitness:\t", gen.best_fitness)
gen.draw_grid()
# Out:
# Best Solution:	 [(1, 9), (9, 19), (11, 12), (22, 14)]
# Generation:	 128
# Fitness:	 1.1375079937194141
