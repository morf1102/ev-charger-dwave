# %%
import numpy as np
from dwave.system import LeapHybridSampler
from dwave.samplers import SimulatedAnnealingSampler
from dimod import ExactCQMSolver

from modules.solvers import QuantumAnnealing

# %%
SHAPE = (50, 50)
POI = 15
CHARGERS = 4
NEW_CHARGERS = 6

SEED = None  # 42

qa = QuantumAnnealing(
    SHAPE, POI, CHARGERS, NEW_CHARGERS, seed=SEED, sampler=LeapHybridSampler()
)
qa.draw_grid()

# %%
# Build BQM
bqm = qa.build_bqm_numpy()

# Calculate score
sampleset = qa.run_bqm(bqm)
score = qa.score_sampleset(sampleset)

# Create scenario output image
print("Score: ", score)
qa.draw_grid()
# Out:
# Score:  257.9495492426598
